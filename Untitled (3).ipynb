# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import math
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
import plotly.express as px
import dash
from dash import dcc, html

df=pd.read_csv('Desktop/data science prject/data2.csv')
print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
cols_string = df.columns
col_counts = dict(df.count(axis=0))
col_types = {c: d for c, d in dict(df.dtypes).items()   if col_counts[c] > 10 }
_is_num = lambda x: x in (np.int64, float)
# separate them
cols_numerical = sorted([col for col, dtp in col_types.items() if _is_num(dtp)])
cols_string = sorted([col for col, dtp in col_types.items() if not _is_num(dtp)])
print(f"NUMERICAL: {cols_numerical}")
print(f"CATEGORICAL: {cols_string}")
# Out:
# NUMERICAL: ['Dalc', 'Fedu', 'G1', 'G2', 'G3', 'Medu', 'Walc', 'absences', 'age', 'failures', 'famrel', 'freetime', 'goout', 'health', 'studytime', 'traveltime']
# CATEGORICAL: ['Fjob', 'Mjob', 'Pstatus', 'activities', 'address', 'famsize', 'famsup', 'guardian', 'higher', 'internet', 'nursery', 'paid', 'reason', 'romantic', 'school', 'schoolsup', 'sex']

# %%
df.drop_duplicates(inplace=True)
for col in cols_string:
    if df[col].dtype == 'object':
        label_encoder = LabelEncoder()
        df[col] = label_encoder.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    int32
#  1   sex         649 non-null    int32
#  2   age         649 non-null    int64
#  3   address     649 non-null    int32
#  4   famsize     649 non-null    int32
#  5   Pstatus     649 non-null    int32
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    int32
#  9   Fjob        649 non-null    int32
#  10  reason      649 non-null    int32
#  11  guardian    649 non-null    int32
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    int32
#  16  famsup      649 non-null    int32
#  17  paid        649 non-null    int32
#  18  activities  649 non-null    int32
#  19  nursery     649 non-null    int32
#  20  higher      649 non-null    int32
#  21  internet    649 non-null    int32
#  22  romantic    649 non-null    int32
#  23  famrel      649 non-null    int64
#  24  freetime    649 non-null    int64
#  25  goout       649 non-null    int64
#  26  Dalc        649 non-null    int64
#  27  Walc        649 non-null    int64
#  28  health      649 non-null    int64
#  29  absences    649 non-null    int64
#  30  G1          649 non-null    int64
#  31  G2          649 non-null    int64
#  32  G3          649 non-null    int64
# dtypes: int32(17), int64(16)
# memory usage: 124.4 KB

# %%
df.describe()
# Out:
#            school         sex         age     address     famsize     Pstatus  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     0.348228    0.409861   16.744222    0.696456    0.295840    0.876733
# std      0.476776    0.492187    1.218138    0.460143    0.456771    0.328996
# min      0.000000    0.000000   15.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   16.000000    0.000000    0.000000    1.000000
# 50%      0.000000    0.000000   17.000000    1.000000    0.000000    1.000000
# 75%      1.000000    1.000000   18.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000   22.000000    1.000000    1.000000    1.000000
#
#              Medu        Fedu        Mjob        Fjob  ...      famrel  \
# count  649.000000  649.000000  649.000000  649.000000  ...  649.000000
# mean     2.514638    2.306626    1.941448    2.224961  ...    3.930663
# std      1.134552    1.099931    1.248317    0.863487  ...    0.955717
# min      0.000000    0.000000    0.000000    0.000000  ...    1.000000
# 25%      2.000000    1.000000    1.000000    2.000000  ...    4.000000
# 50%      2.000000    2.000000    2.000000    2.000000  ...    4.000000
# 75%      4.000000    3.000000    3.000000    3.000000  ...    5.000000
# max      4.000000    4.000000    4.000000    4.000000  ...    5.000000
#
#          freetime       goout        Dalc        Walc      health    absences  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.180277    3.184900    1.502311    2.280431    3.536210    3.659476
# std      1.051093    1.175766    0.924834    1.284380    1.446259    4.640759
# min      1.000000    1.000000    1.000000    1.000000    1.000000    0.000000
# 25%      3.000000    2.000000    1.000000    1.000000    2.000000    0.000000
# 50%      3.000000    3.000000    1.000000    2.000000    4.000000    2.000000
# 75%      4.000000    4.000000    2.000000    3.000000    5.000000    6.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000   32.000000
#
#                G1          G2          G3
# count  649.000000  649.000000  649.000000
# mean    11.399076   11.570108   11.906009
# std      2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000
# 25%     10.000000   10.000000   10.000000
# 50%     11.000000   11.000000   12.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   19.000000
#
# [8 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
ax=sns.boxplot(x=df['G1'])
plt.show()
ax=sns.boxplot(x=df['G2'])
plt.show()
ax=sns.boxplot(x=df['G3'])
plt.show()

# %%
# Assuming df is your DataFrame

# Define the target variables
target_vars = ['G1', 'G2', 'G3']

# Get all features (excluding target variables)
all_features = df.columns.difference(target_vars)

# Pre-calculate histograms, scatter plots, and heatmaps for each feature and target variable combination
histogram_plots = {}
scatter_plots = {}
heatmap_plots = {}

for target in target_vars:
    for feature in all_features:
        # Histogram
        histogram_plots[(target, feature)] = px.histogram(df, x=feature, title=f'Histogram for {feature} ({target})', log_y=True)
        
        # Scatter plot
        scatter_plots[(target, feature)] = px.scatter(df, x=feature, y=target, title=f'Scatter plot of {feature} vs {target}')
        
        # Heatmap
        heatmap_plots[(target, feature)] = px.density_heatmap(df, x=feature, y=target, title=f'Heatmap of {feature} vs {target}')

# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    dcc.Tabs(id='tabs', children=[
        dcc.Tab(label=target, value=target, children=[
            dcc.Tabs(id=f'tabs-{target}', children=[
                dcc.Tab(label=feature, value=feature, children=[
                    dcc.Tabs(id=f'tabs-{target}-{feature}', children=[
                        dcc.Tab(label='Histogram', value='histogram', children=[
                            html.Div([
                                dcc.Graph(id=f'histogram-{target}-{feature}', figure=histogram_plots[(target, feature)])
                            ])
                        ]),
                        dcc.Tab(label='Scatter Plot', value='scatter', children=[
                            html.Div([
                                dcc.Graph(id=f'scatter-{target}-{feature}', figure=scatter_plots[(target, feature)])
                            ])
                        ]),
                        dcc.Tab(label='Heatmap', value='heatmap', children=[
                            html.Div([
                                dcc.Graph(id=f'heatmap-{target}-{feature}', figure=heatmap_plots[(target, feature)])
                            ])
                        ])
                    ])
                ]) for feature in all_features
            ])
        ]) for target in target_vars
    ])
])

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Define the target variables
target_vars = ['G1', 'G2', 'G3']

# Iterate over each target variable
for target in target_vars:
    print(f"\nTarget Variable: {target}")
    
    # Create a set to store effective features
    effective_features = set()
    
    # Iterate over each column in the DataFrame
    for col in df.columns:
        # Skip if the column is one of the target variables
        if col in target_vars:
            continue
        
        print(f'\nThe correlation matrix with {target} for column: {col}')
        
        # Calculate the correlation matrix between the column and the target variable
        matrix = np.corrcoef(df[col], df[target])
        print(matrix)
        
        # Extract the correlation coefficient
        value = matrix[0, 1]
        
        # Determine if the feature is effective based on correlation coefficient
        if abs(value) >= 0.2:
            print('The feature is effective')
            effective_features.add(col)
        else:
            print('The feature is not effective')
    
    # Print the effective features for the current target variable
    print(f'The features with correlation coefficient more than 0.2 for {target} are:', effective_features)
# Out:
# Target Variable: G1
#
# The correlation matrix with G1 for column: school
# [[ 1.         -0.29262558]
#  [-0.29262558  1.        ]]
# The feature is effective
#
# The correlation matrix with G1 for column: sex
# [[ 1.         -0.10410857]
#  [-0.10410857  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: age
# [[ 1.         -0.17432224]
#  [-0.17432224  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: address
# [[1.         0.15712654]
#  [0.15712654 1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: famsize
# [[1.         0.04723007]
#  [0.04723007 1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: Pstatus
# [[1.         0.01525135]
#  [0.01525135 1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: Medu
# [[1.         0.26047229]
#  [0.26047229 1.        ]]
# The feature is effective
#
# The correlation matrix with G1 for column: Fedu
# [[1.         0.21750065]
#  [0.21750065 1.        ]]
# The feature is effective
#
# The correlation matrix with G1 for column: Mjob
# [[1.         0.18155097]
#  [0.18155097 1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: Fjob
# [[1.        0.1098474]
#  [0.1098474 1.       ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: reason
# [[1.         0.15555633]
#  [0.15555633 1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: guardian
# [[ 1.         -0.12267619]
#  [-0.12267619  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: traveltime
# [[ 1.         -0.15411962]
#  [-0.15411962  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: studytime
# [[1.         0.26087538]
#  [0.26087538 1.        ]]
# The feature is effective
#
# The correlation matrix with G1 for column: failures
# [[ 1.         -0.38421048]
#  [-0.38421048  1.        ]]
# The feature is effective
#
# The correlation matrix with G1 for column: schoolsup
# [[ 1.         -0.07177894]
#  [-0.07177894  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: famsup
# [[1.         0.03825523]
#  [0.03825523 1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: paid
# [[ 1.         -0.06278355]
#  [-0.06278355  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: activities
# [[1.         0.08012316]
#  [0.08012316 1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: nursery
# [[1.         0.03117156]
#  [0.03117156 1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: higher
# [[1.         0.34903011]
#  [0.34903011 1.        ]]
# The feature is effective
#
# The correlation matrix with G1 for column: internet
# [[1.         0.13993051]
#  [0.13993051 1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: romantic
# [[ 1.         -0.07497288]
#  [-0.07497288  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: famrel
# [[1.        0.0487946]
#  [0.0487946 1.       ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: freetime
# [[ 1.         -0.09449661]
#  [-0.09449661  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: goout
# [[ 1.         -0.07405263]
#  [-0.07405263  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: Dalc
# [[ 1.         -0.19517093]
#  [-0.19517093  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: Walc
# [[ 1.         -0.15564949]
#  [-0.15564949  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: health
# [[ 1.         -0.05164742]
#  [-0.05164742  1.        ]]
# The feature is not effective
#
# The correlation matrix with G1 for column: absences
# [[ 1.         -0.14714924]
#  [-0.14714924  1.        ]]
# The feature is not effective
# The features with correlation coefficient more than 0.2 for G1 are: {'Medu', 'school', 'studytime', 'higher', 'failures', 'Fedu'}
#
# Target Variable: G2
#
# The correlation matrix with G2 for column: school
# [[ 1.         -0.26977568]
#  [-0.26977568  1.        ]]
# The feature is effective
#
# The correlation matrix with G2 for column: sex
# [[ 1.         -0.10400517]
#  [-0.10400517  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: age
# [[ 1.         -0.10711908]
#  [-0.10711908  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: address
# [[1.        0.1545999]
#  [0.1545999 1.       ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: famsize
# [[1.         0.03889057]
#  [0.03889057 1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: Pstatus
# [[1.         0.01868869]
#  [0.01868869 1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: Medu
# [[1.        0.2640353]
#  [0.2640353 1.       ]]
# The feature is effective
#
# The correlation matrix with G2 for column: Fedu
# [[1.         0.22513893]
#  [0.22513893 1.        ]]
# The feature is effective
#
# The correlation matrix with G2 for column: Mjob
# [[1.         0.15387535]
#  [0.15387535 1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: Fjob
# [[1.         0.08634271]
#  [0.08634271 1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: reason
# [[1.         0.15745939]
#  [0.15745939 1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: guardian
# [[ 1.         -0.09706546]
#  [-0.09706546  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: traveltime
# [[ 1.         -0.15448887]
#  [-0.15448887  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: studytime
# [[1.       0.240498]
#  [0.240498 1.      ]]
# The feature is effective
#
# The correlation matrix with G2 for column: failures
# [[ 1.         -0.38578222]
#  [-0.38578222  1.        ]]
# The feature is effective
#
# The correlation matrix with G2 for column: schoolsup
# [[ 1.         -0.05662363]
#  [-0.05662363  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: famsup
# [[1.         0.03814096]
#  [0.03814096 1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: paid
# [[ 1.         -0.03392515]
#  [-0.03392515  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: activities
# [[1.         0.06715366]
#  [0.06715366 1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: nursery
# [[1.         0.03986733]
#  [0.03986733 1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: higher
# [[1.         0.33195299]
#  [0.33195299 1.        ]]
# The feature is effective
#
# The correlation matrix with G2 for column: internet
# [[1.        0.1479093]
#  [0.1479093 1.       ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: romantic
# [[ 1.         -0.09793651]
#  [-0.09793651  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: famrel
# [[1.         0.08958778]
#  [0.08958778 1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: freetime
# [[ 1.         -0.10667793]
#  [-0.10667793  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: goout
# [[ 1.         -0.07946919]
#  [-0.07946919  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: Dalc
# [[ 1.         -0.18947994]
#  [-0.18947994  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: Walc
# [[ 1.         -0.16485219]
#  [-0.16485219  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: health
# [[ 1.         -0.08217908]
#  [-0.08217908  1.        ]]
# The feature is not effective
#
# The correlation matrix with G2 for column: absences
# [[ 1.         -0.12474493]
#  [-0.12474493  1.        ]]
# The feature is not effective
# The features with correlation coefficient more than 0.2 for G2 are: {'Medu', 'school', 'studytime', 'higher', 'failures', 'Fedu'}
#
# Target Variable: G3
#
# The correlation matrix with G3 for column: school
# [[ 1.         -0.28429416]
#  [-0.28429416  1.        ]]
# The feature is effective
#
# The correlation matrix with G3 for column: sex
# [[ 1.         -0.12907749]
#  [-0.12907749  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: age
# [[ 1.         -0.10650539]
#  [-0.10650539  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: address
# [[1.         0.16763735]
#  [0.16763735 1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: famsize
# [[1.         0.04501637]
#  [0.04501637 1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: Pstatus
# [[ 1.0000000e+00 -7.5392505e-04]
#  [-7.5392505e-04  1.0000000e+00]]
# The feature is not effective
#
# The correlation matrix with G3 for column: Medu
# [[1.         0.24015076]
#  [0.24015076 1.        ]]
# The feature is effective
#
# The correlation matrix with G3 for column: Fedu
# [[1.         0.21179968]
#  [0.21179968 1.        ]]
# The feature is effective
#
# The correlation matrix with G3 for column: Mjob
# [[1.         0.14825209]
#  [0.14825209 1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: Fjob
# [[1.         0.05295329]
#  [0.05295329 1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: reason
# [[1.         0.12496927]
#  [0.12496927 1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: guardian
# [[ 1.         -0.07960894]
#  [-0.07960894  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: traveltime
# [[ 1.         -0.12717297]
#  [-0.12717297  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: studytime
# [[1.         0.24978869]
#  [0.24978869 1.        ]]
# The feature is effective
#
# The correlation matrix with G3 for column: failures
# [[ 1.         -0.39331555]
#  [-0.39331555  1.        ]]
# The feature is effective
#
# The correlation matrix with G3 for column: schoolsup
# [[ 1.         -0.06640475]
#  [-0.06640475  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: famsup
# [[1.         0.05920556]
#  [0.05920556 1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: paid
# [[ 1.         -0.05489791]
#  [-0.05489791  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: activities
# [[1.         0.05979145]
#  [0.05979145 1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: nursery
# [[1.         0.02875236]
#  [0.02875236 1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: higher
# [[1.         0.33217159]
#  [0.33217159 1.        ]]
# The feature is effective
#
# The correlation matrix with G3 for column: internet
# [[1.         0.15002485]
#  [0.15002485 1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: romantic
# [[ 1.         -0.09058288]
#  [-0.09058288  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: famrel
# [[1.         0.06336113]
#  [0.06336113 1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: freetime
# [[ 1.         -0.12270493]
#  [-0.12270493  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: goout
# [[ 1.         -0.08764072]
#  [-0.08764072  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: Dalc
# [[ 1.        -0.2047194]
#  [-0.2047194  1.       ]]
# The feature is effective
#
# The correlation matrix with G3 for column: Walc
# [[ 1.         -0.17661887]
#  [-0.17661887  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: health
# [[ 1.         -0.09885124]
#  [-0.09885124  1.        ]]
# The feature is not effective
#
# The correlation matrix with G3 for column: absences
# [[ 1.         -0.09137906]
#  [-0.09137906  1.        ]]
# The feature is not effective
# The features with correlation coefficient more than 0.2 for G3 are: {'Medu', 'school', 'studytime', 'higher', 'Dalc', 'failures', 'Fedu'}

# %%
for target in target_vars:
    sigcor = set()
    nosigcor = set()
    columns = set()

    print(f"\nProcessing for target variable: {target}")

    for col in df.columns:
        if col in target_vars:
            continue
        columns.add(col)
        correlation_coefficient, p_value = stats.pearsonr(df[col], df[target])

        print(f'Correlation coefficient between {target} and {col}: {correlation_coefficient}')
        print(f'p-value: {p_value}')

        # Interpret the results
        alpha = 0.05
        if p_value < alpha:
            print(f"Reject the null hypothesis. There is a significant correlation between {target} and {col}")
            sigcor.add(col)
        else:
            print(f"Fail to reject the null hypothesis. There is no significant correlation between {target} and {col}")
            nosigcor.add(col)

    # Calculate features with significant correlation more than 0.2 and less than 0.2
    sigcor_more_0_2 = {col for col in sigcor if abs(stats.pearsonr(df[col], df[target])[0]) >= 0.2}
    sigcor_less_0_2 = sigcor.difference(sigcor_more_0_2)

    # Print the results
    print(f'The features with significant correlation (|correlation coefficient| >= 0.2) for {target} are:', sigcor_more_0_2)
    print(f'The features with significant correlation (|correlation coefficient| < 0.2) for {target} are:', sigcor_less_0_2)
    print(f'The features with no significant correlation for {target} are:', nosigcor)
# Out:
# Processing for target variable: G1
# Correlation coefficient between G1 and school: -0.2926255804242827
# p-value: 2.793393844453102e-14
# Reject the null hypothesis. There is a significant correlation between G1 and school
# Correlation coefficient between G1 and sex: -0.10410856829980733
# p-value: 0.007946869649725062
# Reject the null hypothesis. There is a significant correlation between G1 and sex
# Correlation coefficient between G1 and age: -0.174322239527609
# p-value: 7.946331176855924e-06
# Reject the null hypothesis. There is a significant correlation between G1 and age
# Correlation coefficient between G1 and address: 0.15712653987366298
# p-value: 5.815994186504203e-05
# Reject the null hypothesis. There is a significant correlation between G1 and address
# Correlation coefficient between G1 and famsize: 0.04723006698519027
# p-value: 0.2295341772970874
# Fail to reject the null hypothesis. There is no significant correlation between G1 and famsize
# Correlation coefficient between G1 and Pstatus: 0.015251348919786994
# p-value: 0.6981574090767858
# Fail to reject the null hypothesis. There is no significant correlation between G1 and Pstatus
# Correlation coefficient between G1 and Medu: 0.260472289565232
# p-value: 1.5888905668917976e-11
# Reject the null hypothesis. There is a significant correlation between G1 and Medu
# Correlation coefficient between G1 and Fedu: 0.21750065064752375
# p-value: 2.175954739563109e-08
# Reject the null hypothesis. There is a significant correlation between G1 and Fedu
# Correlation coefficient between G1 and Mjob: 0.1815509683587639
# p-value: 3.2410722917817383e-06
# Reject the null hypothesis. There is a significant correlation between G1 and Mjob
# Correlation coefficient between G1 and Fjob: 0.10984740463713606
# p-value: 0.005086522802837781
# Reject the null hypothesis. There is a significant correlation between G1 and Fjob
# Correlation coefficient between G1 and reason: 0.15555632639290473
# p-value: 6.906578655877458e-05
# Reject the null hypothesis. There is a significant correlation between G1 and reason
# Correlation coefficient between G1 and guardian: -0.12267619473063582
# p-value: 0.001741861468904224
# Reject the null hypothesis. There is a significant correlation between G1 and guardian
# Correlation coefficient between G1 and traveltime: -0.1541196211128153
# p-value: 8.071079731187077e-05
# Reject the null hypothesis. There is a significant correlation between G1 and traveltime
# Correlation coefficient between G1 and studytime: 0.2608753803131899
# p-value: 1.474934203829126e-11
# Reject the null hypothesis. There is a significant correlation between G1 and studytime
# Correlation coefficient between G1 and failures: -0.3842104760044191
# p-value: 2.9390468059442812e-24
# Reject the null hypothesis. There is a significant correlation between G1 and failures
# Correlation coefficient between G1 and schoolsup: -0.07177894143044515
# p-value: 0.0676343201481782
# Fail to reject the null hypothesis. There is no significant correlation between G1 and schoolsup
# Correlation coefficient between G1 and famsup: 0.03825522796734802
# p-value: 0.3305295907196811
# Fail to reject the null hypothesis. There is no significant correlation between G1 and famsup
# Correlation coefficient between G1 and paid: -0.06278355391046007
# p-value: 0.11005756785590161
# Fail to reject the null hypothesis. There is no significant correlation between G1 and paid
# Correlation coefficient between G1 and activities: 0.08012316046929392
# p-value: 0.04129831821001719
# Reject the null hypothesis. There is a significant correlation between G1 and activities
# Correlation coefficient between G1 and nursery: 0.031171557655061032
# p-value: 0.4279105822765041
# Fail to reject the null hypothesis. There is no significant correlation between G1 and nursery
# Correlation coefficient between G1 and higher: 0.3490301134412208
# p-value: 4.9855460795870964e-20
# Reject the null hypothesis. There is a significant correlation between G1 and higher
# Correlation coefficient between G1 and internet: 0.13993051274728235
# p-value: 0.00034951812591427716
# Reject the null hypothesis. There is a significant correlation between G1 and internet
# Correlation coefficient between G1 and romantic: -0.07497288119974742
# p-value: 0.05626526699291732
# Fail to reject the null hypothesis. There is no significant correlation between G1 and romantic
# Correlation coefficient between G1 and famrel: 0.04879460349123019
# p-value: 0.21445466680377187
# Fail to reject the null hypothesis. There is no significant correlation between G1 and famrel
# Correlation coefficient between G1 and freetime: -0.09449660588180041
# p-value: 0.016035959944805826
# Reject the null hypothesis. There is a significant correlation between G1 and freetime
# Correlation coefficient between G1 and goout: -0.07405263312184833
# p-value: 0.059365213179206344
# Fail to reject the null hypothesis. There is no significant correlation between G1 and goout
# Correlation coefficient between G1 and Dalc: -0.1951709341928913
# p-value: 5.421761704014185e-07
# Reject the null hypothesis. There is a significant correlation between G1 and Dalc
# Correlation coefficient between G1 and Walc: -0.15564948637866213
# p-value: 6.836826533624026e-05
# Reject the null hypothesis. There is a significant correlation between G1 and Walc
# Correlation coefficient between G1 and health: -0.05164741507284606
# p-value: 0.18881817473047022
# Fail to reject the null hypothesis. There is no significant correlation between G1 and health
# Correlation coefficient between G1 and absences: -0.14714924176398442
# p-value: 0.00016858167247297724
# Reject the null hypothesis. There is a significant correlation between G1 and absences
# The features with significant correlation (|correlation coefficient| >= 0.2) for G1 are: {'studytime', 'higher', 'school', 'Medu', 'failures', 'Fedu'}
# The features with significant correlation (|correlation coefficient| < 0.2) for G1 are: {'Fjob', 'reason', 'activities', 'internet', 'age', 'Dalc', 'freetime', 'absences', 'address', 'Mjob', 'sex', 'traveltime', 'guardian', 'Walc'}
# The features with no significant correlation for G1 are: {'famsize', 'schoolsup', 'nursery', 'famrel', 'goout', 'Pstatus', 'famsup', 'romantic', 'paid', 'health'}
#
# Processing for target variable: G2
# Correlation coefficient between G2 and school: -0.26977568296417925
# p-value: 2.7603868370761268e-12
# Reject the null hypothesis. There is a significant correlation between G2 and school
# Correlation coefficient between G2 and sex: -0.10400516844766886
# p-value: 0.008009520801082876
# Reject the null hypothesis. There is a significant correlation between G2 and sex
# Correlation coefficient between G2 and age: -0.1071190788160785
# p-value: 0.006304440545362564
# Reject the null hypothesis. There is a significant correlation between G2 and age
# Correlation coefficient between G2 and address: 0.15459989980315172
# p-value: 7.662612078435418e-05
# Reject the null hypothesis. There is a significant correlation between G2 and address
# Correlation coefficient between G2 and famsize: 0.03889057102806412
# p-value: 0.3225554026796903
# Fail to reject the null hypothesis. There is no significant correlation between G2 and famsize
# Correlation coefficient between G2 and Pstatus: 0.018688693701555445
# p-value: 0.6346251061953812
# Fail to reject the null hypothesis. There is no significant correlation between G2 and Pstatus
# Correlation coefficient between G2 and Medu: 0.2640352996954111
# p-value: 8.193733683835511e-12
# Reject the null hypothesis. There is a significant correlation between G2 and Medu
# Correlation coefficient between G2 and Fedu: 0.22513892965217105
# p-value: 6.668089715693924e-09
# Reject the null hypothesis. There is a significant correlation between G2 and Fedu
# Correlation coefficient between G2 and Mjob: 0.15387535058327614
# p-value: 8.286621979292403e-05
# Reject the null hypothesis. There is a significant correlation between G2 and Mjob
# Correlation coefficient between G2 and Fjob: 0.08634270788195562
# p-value: 0.027843079211626744
# Reject the null hypothesis. There is a significant correlation between G2 and Fjob
# Correlation coefficient between G2 and reason: 0.15745939412694981
# p-value: 5.6067386414508684e-05
# Reject the null hypothesis. There is a significant correlation between G2 and reason
# Correlation coefficient between G2 and guardian: -0.09706545671333015
# p-value: 0.013365986239415454
# Reject the null hypothesis. There is a significant correlation between G2 and guardian
# Correlation coefficient between G2 and traveltime: -0.1544888705886382
# p-value: 7.75526950755382e-05
# Reject the null hypothesis. There is a significant correlation between G2 and traveltime
# Correlation coefficient between G2 and studytime: 0.24049799907999117
# p-value: 5.424410252333764e-10
# Reject the null hypothesis. There is a significant correlation between G2 and studytime
# Correlation coefficient between G2 and failures: -0.38578221523188244
# p-value: 1.8486334659888678e-24
# Reject the null hypothesis. There is a significant correlation between G2 and failures
# Correlation coefficient between G2 and schoolsup: -0.05662363476840519
# p-value: 0.14961588367477996
# Fail to reject the null hypothesis. There is no significant correlation between G2 and schoolsup
# Correlation coefficient between G2 and famsup: 0.03814096254061582
# p-value: 0.33197712634797893
# Fail to reject the null hypothesis. There is no significant correlation between G2 and famsup
# Correlation coefficient between G2 and paid: -0.03392514950078144
# p-value: 0.388224498470702
# Fail to reject the null hypothesis. There is no significant correlation between G2 and paid
# Correlation coefficient between G2 and activities: 0.06715365536871921
# p-value: 0.08737622644247141
# Fail to reject the null hypothesis. There is no significant correlation between G2 and activities
# Correlation coefficient between G2 and nursery: 0.03986733425466664
# p-value: 0.31054233734370756
# Fail to reject the null hypothesis. There is no significant correlation between G2 and nursery
# Correlation coefficient between G2 and higher: 0.3319529866464954
# p-value: 3.691722149280464e-18
# Reject the null hypothesis. There is a significant correlation between G2 and higher
# Correlation coefficient between G2 and internet: 0.14790929756717536
# p-value: 0.00015581407731711037
# Reject the null hypothesis. There is a significant correlation between G2 and internet
# Correlation coefficient between G2 and romantic: -0.09793650813758163
# p-value: 0.0125541408743563
# Reject the null hypothesis. There is a significant correlation between G2 and romantic
# Correlation coefficient between G2 and famrel: 0.08958778299759289
# p-value: 0.022460834734956373
# Reject the null hypothesis. There is a significant correlation between G2 and famrel
# Correlation coefficient between G2 and freetime: -0.10667792651255559
# p-value: 0.006524280613622508
# Reject the null hypothesis. There is a significant correlation between G2 and freetime
# Correlation coefficient between G2 and goout: -0.0794691939728879
# p-value: 0.042989234489031754
# Reject the null hypothesis. There is a significant correlation between G2 and goout
# Correlation coefficient between G2 and Dalc: -0.18947993515773695
# p-value: 1.162661430234072e-06
# Reject the null hypothesis. There is a significant correlation between G2 and Dalc
# Correlation coefficient between G2 and Walc: -0.16485218676720817
# p-value: 2.4375987335133728e-05
# Reject the null hypothesis. There is a significant correlation between G2 and Walc
# Correlation coefficient between G2 and health: -0.08217908362558918
# p-value: 0.0363440769638186
# Reject the null hypothesis. There is a significant correlation between G2 and health
# Correlation coefficient between G2 and absences: -0.1247449334714272
# p-value: 0.001451262589183795
# Reject the null hypothesis. There is a significant correlation between G2 and absences
# The features with significant correlation (|correlation coefficient| >= 0.2) for G2 are: {'studytime', 'higher', 'school', 'Medu', 'failures', 'Fedu'}
# The features with significant correlation (|correlation coefficient| < 0.2) for G2 are: {'Fjob', 'reason', 'internet', 'age', 'Dalc', 'freetime', 'absences', 'famrel', 'address', 'goout', 'Mjob', 'sex', 'traveltime', 'guardian', 'romantic', 'Walc', 'health'}
# The features with no significant correlation for G2 are: {'activities', 'famsize', 'schoolsup', 'nursery', 'Pstatus', 'famsup', 'paid'}
#
# Processing for target variable: G3
# Correlation coefficient between G3 and school: -0.2842941636006064
# p-value: 1.566199092300338e-13
# Reject the null hypothesis. There is a significant correlation between G3 and school
# Correlation coefficient between G3 and sex: -0.1290774866044329
# p-value: 0.0009815287061373866
# Reject the null hypothesis. There is a significant correlation between G3 and sex
# Correlation coefficient between G3 and age: -0.10650539063847848
# p-value: 0.006612115288655546
# Reject the null hypothesis. There is a significant correlation between G3 and age
# Correlation coefficient between G3 and address: 0.16763734858992002
# p-value: 1.76415346092233e-05
# Reject the null hypothesis. There is a significant correlation between G3 and address
# Correlation coefficient between G3 and famsize: 0.04501636801724973
# p-value: 0.2521332216658384
# Fail to reject the null hypothesis. There is no significant correlation between G3 and famsize
# Correlation coefficient between G3 and Pstatus: -0.0007539250498183833
# p-value: 0.984705825950265
# Fail to reject the null hypothesis. There is no significant correlation between G3 and Pstatus
# Correlation coefficient between G3 and Medu: 0.240150756573595
# p-value: 5.752228899275774e-10
# Reject the null hypothesis. There is a significant correlation between G3 and Medu
# Correlation coefficient between G3 and Fedu: 0.21179967911445194
# p-value: 5.116520322562035e-08
# Reject the null hypothesis. There is a significant correlation between G3 and Fedu
# Correlation coefficient between G3 and Mjob: 0.14825209205800652
# p-value: 0.00015035795710802483
# Reject the null hypothesis. There is a significant correlation between G3 and Mjob
# Correlation coefficient between G3 and Fjob: 0.05295328928380919
# p-value: 0.1778658513811211
# Fail to reject the null hypothesis. There is no significant correlation between G3 and Fjob
# Correlation coefficient between G3 and reason: 0.12496926870515813
# p-value: 0.00142258827913758
# Reject the null hypothesis. There is a significant correlation between G3 and reason
# Correlation coefficient between G3 and guardian: -0.07960893515506366
# p-value: 0.04262309164139274
# Reject the null hypothesis. There is a significant correlation between G3 and guardian
# Correlation coefficient between G3 and traveltime: -0.12717296675842052
# p-value: 0.0011673572884927687
# Reject the null hypothesis. There is a significant correlation between G3 and traveltime
# Correlation coefficient between G3 and studytime: 0.2497886899988629
# p-value: 1.0908085906064512e-10
# Reject the null hypothesis. There is a significant correlation between G3 and studytime
# Correlation coefficient between G3 and failures: -0.3933155480419927
# p-value: 1.9341532697778135e-25
# Reject the null hypothesis. There is a significant correlation between G3 and failures
# Correlation coefficient between G3 and schoolsup: -0.06640474759529706
# p-value: 0.09097103846579756
# Fail to reject the null hypothesis. There is no significant correlation between G3 and schoolsup
# Correlation coefficient between G3 and famsup: 0.059205555545787686
# p-value: 0.1318865120420259
# Fail to reject the null hypothesis. There is no significant correlation between G3 and famsup
# Correlation coefficient between G3 and paid: -0.054897907823289495
# p-value: 0.16244124863570159
# Fail to reject the null hypothesis. There is no significant correlation between G3 and paid
# Correlation coefficient between G3 and activities: 0.059791450427086563
# p-value: 0.12809905950542763
# Fail to reject the null hypothesis. There is no significant correlation between G3 and activities
# Correlation coefficient between G3 and nursery: 0.028752359319059805
# p-value: 0.46464524309822697
# Fail to reject the null hypothesis. There is no significant correlation between G3 and nursery
# Correlation coefficient between G3 and higher: 0.3321715908673613
# p-value: 3.499659592829981e-18
# Reject the null hypothesis. There is a significant correlation between G3 and higher
# Correlation coefficient between G3 and internet: 0.15002485385078743
# p-value: 0.00012489173447452462
# Reject the null hypothesis. There is a significant correlation between G3 and internet
# Correlation coefficient between G3 and romantic: -0.0905828835959994
# p-value: 0.021002471524650963
# Reject the null hypothesis. There is a significant correlation between G3 and romantic
# Correlation coefficient between G3 and famrel: 0.06336112772983042
# p-value: 0.10681752001746593
# Fail to reject the null hypothesis. There is no significant correlation between G3 and famrel
# Correlation coefficient between G3 and freetime: -0.12270492583369744
# p-value: 0.0017374839458199954
# Reject the null hypothesis. There is a significant correlation between G3 and freetime
# Correlation coefficient between G3 and goout: -0.08764072272424224
# p-value: 0.025569874567814767
# Reject the null hypothesis. There is a significant correlation between G3 and goout
# Correlation coefficient between G3 and Dalc: -0.20471939724815688
# p-value: 1.4320359116837248e-07
# Reject the null hypothesis. There is a significant correlation between G3 and Dalc
# Correlation coefficient between G3 and Walc: -0.1766188742096643
# p-value: 5.999493279858726e-06
# Reject the null hypothesis. There is a significant correlation between G3 and Walc
# Correlation coefficient between G3 and health: -0.09885124139431788
# p-value: 0.011748773079979853
# Reject the null hypothesis. There is a significant correlation between G3 and health
# Correlation coefficient between G3 and absences: -0.09137905643875616
# p-value: 0.0198956239391607
# Reject the null hypothesis. There is a significant correlation between G3 and absences
# The features with significant correlation (|correlation coefficient| >= 0.2) for G3 are: {'studytime', 'higher', 'Dalc', 'Medu', 'school', 'failures', 'Fedu'}
# The features with significant correlation (|correlation coefficient| < 0.2) for G3 are: {'reason', 'internet', 'age', 'freetime', 'absences', 'address', 'goout', 'Mjob', 'sex', 'traveltime', 'guardian', 'romantic', 'Walc', 'health'}
# The features with no significant correlation for G3 are: {'Fjob', 'paid', 'activities', 'famsize', 'schoolsup', 'nursery', 'famrel', 'famsup', 'Pstatus'}

# %%
target_vars = ['G1', 'G2', 'G3']
features = df.drop(columns=target_vars)

# Print out the columns for verification
print("Features:", features.columns)
print("Target Variables:", target_vars)
results = {}

for target in target_vars:
    X = features  # All columns except the target
    y = df[target]
    
    # Add a constant to the model (intercept)
    X = sm.add_constant(X)
    
    # Fit the regression model
    model = sm.OLS(y, X).fit()
    
    # Store the results
    results[target] = model
    
    # Print the summary for each model
    print(f"Regression Results for {target}:")
    print(model.summary())
    print("\n")
# Out:
# Features: Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences'],
#       dtype='object')
# Target Variables: ['G1', 'G2', 'G3']
# Regression Results for G1:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G1   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     11.35
# Date:                Sun, 19 May 2024   Prob (F-statistic):           8.05e-42
# Time:                        11:50:17   Log-Likelihood:                -1433.4
# No. Observations:                 649   AIC:                             2929.
# Df Residuals:                     618   BIC:                             3067.
# Df Model:                          30
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.5351      1.617      6.515      0.000       7.360      13.710
# school        -1.2307      0.219     -5.611      0.000      -1.661      -0.800
# sex           -0.5005      0.210     -2.379      0.018      -0.914      -0.087
# age           -0.0220      0.085     -0.260      0.795      -0.188       0.144
# address        0.1358      0.220      0.618      0.537      -0.296       0.567
# famsize        0.3151      0.206      1.529      0.127      -0.090       0.720
# Pstatus        0.1722      0.292      0.590      0.555      -0.400       0.745
# Medu           0.1517      0.117      1.300      0.194      -0.077       0.381
# Fedu           0.1129      0.110      1.026      0.305      -0.103       0.329
# Mjob           0.0904      0.084      1.077      0.282      -0.074       0.255
# Fjob           0.1135      0.109      1.042      0.298      -0.100       0.327
# reason         0.1104      0.078      1.409      0.159      -0.043       0.264
# guardian      -0.2583      0.186     -1.387      0.166      -0.624       0.107
# traveltime    -0.0430      0.133     -0.324      0.746      -0.304       0.218
# studytime      0.3819      0.117      3.262      0.001       0.152       0.612
# failures      -0.9485      0.171     -5.551      0.000      -1.284      -0.613
# schoolsup     -1.2928      0.305     -4.243      0.000      -1.891      -0.694
# famsup        -0.0934      0.191     -0.489      0.625      -0.469       0.282
# paid          -0.5044      0.387     -1.304      0.193      -1.264       0.255
# activities     0.2192      0.186      1.178      0.239      -0.146       0.585
# nursery       -0.1933      0.229     -0.846      0.398      -0.642       0.255
# higher         1.4781      0.321      4.602      0.000       0.847       2.109
# internet       0.0968      0.231      0.419      0.675      -0.357       0.550
# romantic      -0.1571      0.193     -0.814      0.416      -0.536       0.222
# famrel         0.0094      0.097      0.097      0.923      -0.182       0.201
# freetime      -0.0580      0.094     -0.614      0.539      -0.244       0.127
# goout          0.0135      0.090      0.150      0.881      -0.163       0.190
# Dalc          -0.1906      0.127     -1.507      0.132      -0.439       0.058
# Walc          -0.0743      0.098     -0.756      0.450      -0.267       0.119
# health        -0.0532      0.064     -0.828      0.408      -0.179       0.073
# absences      -0.0624      0.021     -2.993      0.003      -0.103      -0.021
# ==============================================================================
# Omnibus:                       17.000   Durbin-Watson:                   1.763
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.249
# Skew:                          -0.008   Prob(JB):                     2.22e-08
# Kurtosis:                       4.142   Cond. No.                         360.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for G2:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G2   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.302
# Method:                 Least Squares   F-statistic:                     10.34
# Date:                Sun, 19 May 2024   Prob (F-statistic):           7.03e-38
# Time:                        11:50:17   Log-Likelihood:                -1482.4
# No. Observations:                 649   AIC:                             3027.
# Df Residuals:                     618   BIC:                             3166.
# Df Model:                          30
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.2625      1.744      4.165      0.000       3.838      10.687
# school        -1.1011      0.237     -4.655      0.000      -1.566      -0.637
# sex           -0.4745      0.227     -2.091      0.037      -0.920      -0.029
# age            0.1725      0.091      1.888      0.059      -0.007       0.352
# address        0.1997      0.237      0.843      0.399      -0.265       0.665
# famsize        0.2689      0.222      1.210      0.227      -0.167       0.705
# Pstatus        0.2220      0.314      0.706      0.481      -0.396       0.839
# Medu           0.1994      0.126      1.585      0.114      -0.048       0.446
# Fedu           0.1649      0.119      1.390      0.165      -0.068       0.398
# Mjob           0.0201      0.091      0.222      0.825      -0.158       0.198
# Fjob           0.0515      0.117      0.438      0.661      -0.179       0.282
# reason         0.1098      0.084      1.300      0.194      -0.056       0.276
# guardian      -0.1778      0.201     -0.885      0.376      -0.572       0.217
# traveltime    -0.0495      0.143     -0.346      0.730      -0.331       0.232
# studytime      0.3251      0.126      2.576      0.010       0.077       0.573
# failures      -1.1761      0.184     -6.381      0.000      -1.538      -0.814
# schoolsup     -1.0625      0.329     -3.233      0.001      -1.708      -0.417
# famsup        -0.0831      0.206     -0.403      0.687      -0.488       0.322
# paid          -0.2335      0.417     -0.559      0.576      -1.053       0.586
# activities     0.2098      0.201      1.046      0.296      -0.184       0.604
# nursery       -0.1634      0.246     -0.663      0.508      -0.647       0.321
# higher         1.5376      0.346      4.439      0.000       0.857       2.218
# internet       0.1822      0.249      0.732      0.465      -0.307       0.671
# romantic      -0.3857      0.208     -1.854      0.064      -0.794       0.023
# famrel         0.1562      0.105      1.486      0.138      -0.050       0.363
# freetime      -0.0750      0.102     -0.736      0.462      -0.275       0.125
# goout         -0.0399      0.097     -0.412      0.680      -0.230       0.150
# Dalc          -0.1718      0.136     -1.259      0.208      -0.440       0.096
# Walc          -0.1022      0.106     -0.963      0.336      -0.311       0.106
# health        -0.1274      0.069     -1.837      0.067      -0.264       0.009
# absences      -0.0515      0.022     -2.291      0.022      -0.096      -0.007
# ==============================================================================
# Omnibus:                       56.240   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.662
# Skew:                          -0.403   Prob(JB):                     1.75e-36
# Kurtosis:                       5.332   Cond. No.                         360.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for G3:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G3   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.314
# Method:                 Least Squares   F-statistic:                     10.87
# Date:                Sun, 19 May 2024   Prob (F-statistic):           5.97e-40
# Time:                        11:50:17   Log-Likelihood:                -1544.0
# No. Observations:                 649   AIC:                             3150.
# Df Residuals:                     618   BIC:                             3289.
# Df Model:                          30
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.8975      1.917      4.119      0.000       4.132      11.663
# school        -1.3491      0.260     -5.188      0.000      -1.860      -0.838
# sex           -0.6017      0.249     -2.412      0.016      -1.092      -0.112
# age            0.1850      0.100      1.842      0.066      -0.012       0.382
# address        0.3104      0.260      1.192      0.234      -0.201       0.822
# famsize        0.3145      0.244      1.287      0.198      -0.165       0.794
# Pstatus        0.1179      0.346      0.341      0.733      -0.561       0.797
# Medu           0.1384      0.138      1.001      0.317      -0.133       0.410
# Fedu           0.2101      0.130      1.611      0.108      -0.046       0.466
# Mjob           0.0502      0.100      0.504      0.614      -0.145       0.246
# Fjob          -0.0604      0.129     -0.468      0.640      -0.314       0.193
# reason         0.0292      0.093      0.314      0.754      -0.153       0.212
# guardian      -0.1425      0.221     -0.645      0.519      -0.576       0.291
# traveltime     0.0949      0.158      0.603      0.547      -0.214       0.404
# studytime      0.3838      0.139      2.765      0.006       0.111       0.656
# failures      -1.3826      0.203     -6.823      0.000      -1.781      -0.985
# schoolsup     -1.3019      0.361     -3.603      0.000      -2.012      -0.592
# famsup         0.0462      0.227      0.204      0.839      -0.399       0.491
# paid          -0.4890      0.459     -1.066      0.287      -1.390       0.412
# activities     0.2531      0.221      1.147      0.252      -0.180       0.686
# nursery       -0.2599      0.271     -0.959      0.338      -0.792       0.272
# higher         1.7371      0.381      4.561      0.000       0.989       2.485
# internet       0.2847      0.274      1.040      0.299      -0.253       0.822
# romantic      -0.4092      0.229     -1.789      0.074      -0.858       0.040
# famrel         0.1124      0.116      0.973      0.331      -0.115       0.339
# freetime      -0.1141      0.112     -1.019      0.309      -0.334       0.106
# goout         -0.0596      0.106     -0.559      0.576      -0.269       0.150
# Dalc          -0.2398      0.150     -1.599      0.110      -0.534       0.055
# Walc          -0.1079      0.117     -0.925      0.355      -0.337       0.121
# health        -0.1738      0.076     -2.280      0.023      -0.324      -0.024
# absences      -0.0395      0.025     -1.598      0.111      -0.088       0.009
# ==============================================================================
# Omnibus:                      127.296   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              414.886
# Skew:                          -0.916   Prob(JB):                     8.10e-91
# Kurtosis:                       6.462   Cond. No.                         360.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Define a dictionary to store significant features for each target variable
significant_features = {}

# Iterate over each target variable
for target in target_vars:
    # Get the regression results for the target variable
    model = results[target]
    
    # Extract the p-values of the features
    p_values = model.pvalues[1:]  # Exclude the intercept term
    
    # Filter the features based on their p-values
    significant_features[target] = list(features.columns[p_values < 0.05])

# Print the significant features for each target variable
for target, features_list in significant_features.items():
    print(f"Significant features for {target}: {features_list}")
# Out:
# Significant features for G1: ['school', 'sex', 'studytime', 'failures', 'schoolsup', 'higher', 'absences']
# Significant features for G2: ['school', 'sex', 'studytime', 'failures', 'schoolsup', 'higher', 'absences']
# Significant features for G3: ['school', 'sex', 'studytime', 'failures', 'schoolsup', 'higher', 'health']

# %%
# Define a dictionary to store significant features for each target variable
significant_features = {}

# Iterate over each target variable
for target in target_vars:
    # Get the regression results for the target variable
    model = results[target]
    
    # Extract the p-values of the features
    p_values = model.pvalues[1:]  # Exclude the intercept term
    
    # Filter the features based on their p-values
    significant_features[target] = list(features.columns[p_values < 0.05])

# Perform regression for each target variable
for target in target_vars:
    # Select significant features for the target variable
    X = df[significant_features[target]]
    y = df[target]
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    
    # Fit the linear regression model
    model1 = LinearRegression()
    model1.fit(X_train, y_train) 
    
    # Predict on the test set
    y_hat = model1.predict(X_test)
    
    # Evaluate the model
    mse = mean_squared_error(y_test, y_hat)
    r2 = r2_score(y_test, y_hat)
    
    # Print the evaluation metrics
    print(f"Target Variable: {target}")
    print('MSE:', mse)
    print('r2_score:', r2)
    
    # Plot the scatter plot of actual vs. predicted values
    plt.scatter(y_test, y_hat)
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.title(f'{target} - Actual vs. Predicted')
    plt.show()
# Out:
# Target Variable: G1
# MSE: 4.777099151986563
# r2_score: 0.29758321440999413
# Target Variable: G2
# MSE: 5.800346348505093
# r2_score: 0.24035110321730235
# Target Variable: G3
# MSE: 5.226283432400877
# r2_score: 0.26430840601407
